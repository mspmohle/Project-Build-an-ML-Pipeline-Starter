# %%
import os
print("CWD:", os.getcwd())
print("Exists src?:", os.path.isdir("src"))
print("Contents of src:", os.listdir("src") if os.path.isdir("src") else "no src here")
# Create subfolder if needed
os.makedirs("src/sample", exist_ok=True)
# Out:
# CWD: /home/parallels/Project-Build-an-ML-Pipeline-Starter
# Exists src?: True
# Contents of src: ['train_random_forest', 'basic_cleaning', 'eda', 'data_check']
